# %% [markdown]
# ### Parâmetros - Estimadores (amostrais)
#
#   - Media
#   - Mediana
#   - Moda
#   - Desvio Padrão

# %% [markdown]
# ### Estatística descritiva
#
#   - Parâmetros
#   - Simetria
#   - Quartis, decis, percentis
#   - Máximo e Mínimo
#   - Outliers (valores fora curva) --> distribuição normal

# %%
import os, sys, math
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats

from statistics import mode

import matplotlib.pyplot as plt # matplotlib e seu alias plt
# %matplotlib inline

# %%
# metodo estatístico
def mostra_estatistica(lista: list, verbose:bool=False):
    mu = np.mean(lista)
    med = np.median(lista)
    mod = mode(lista)
    SSD = np.std(lista)
    n = len(lista)

    stri = f"N={n} - media={mu:.2f} median={med:.2f} moda={mod:.2f} e SSD={SSD:.2f}"
    if verbose: print(stri)

    return n, mu, med, mod, SSD, stri

# %% [markdown]
# ### Amostragem uniforme de 0 a 9

# %%
N = 20
divs = 10
nums = np.random.randint(0, divs, N)

n, mu, med, mod, SSD, stri = mostra_estatistica(nums, verbose=True)

### N amostras, de números inteiros de 0 a 9
nums

# %% [markdown]
# ### Gráfico de Frequências
#
# - uniforme, logo simétrico

# %%
N = 10000
divs = 10
val_esperado = (1+divs)/2
freq_esperada = N/divs

nums = np.random.randint(1, divs+1, N)
n, mu, med, mod, SSD, stri = mostra_estatistica(nums, verbose=False)

title = f"Gráfico de Frequências Discreto e Uniforme com {N} amostras"
title += f"\n{stri} - valor esperado {val_esperado}"
title += "\ncom poucas jogadas o erro é muito grande, aleatório"

plt.figure(figsize=(10,7))
ax = sns.histplot(nums, bins=divs, color='darkcyan')
ax.set_title(title)
ax.set_xticks(np.arange(1, divs+1));

ax.axhline(freq_esperada, color='black');

# %% [markdown]
# ### Amostragem uniforme de 1 a 40

# %%
N = 100000
divs = 40
val_esperado = (1+divs)/2
freq_esperada = N/divs

nums = np.random.randint(1, divs+1, N)
n, mu, med, mod, SSD, stri = mostra_estatistica(nums, verbose=False)

title = f"Gráfico de Frequências Discreto e Uniforme com {N} amostras"
title += f"\n{stri} - valor esperado {val_esperado}"
title += "\ncom poucas jogadas o erro é muito grande, aleatório"

plt.figure(figsize=(10,7))
ax = sns.histplot(nums, bins=divs, color='darkcyan')
ax.set_title(title)
ax.set_xticks(np.arange(0, divs+1, step=5));

ax.axhline(freq_esperada, color='black');

# %% [markdown]
# ### Entendem a simetria analisando os números a seguir?

# %%
mini = np.min(nums)
maxi = np.max(nums)
media   = np.mean(nums)
ssd     = np.std(nums)
mediana = np.median(nums)
moda = mode(nums)

f"[mini, max]=[{mini}, {maxi}], media={mu:.2f} median={med:.2f} moda={mod:.2f} e SSD={SSD:.2f}"

# %%
type(nums), len(nums)

# %%
# metodo estatístico
def mostra_estatistica(lista: list, verbose:bool=False):

    mini = np.min(lista)
    maxi = np.max(lista)

    n = len(lista)

    mu = np.mean(lista)
    med = np.median(lista)
    moda = mode(lista)

    SSD = np.std(lista)

    stri = f"N={n} - [mini, max]=[{mini}, {maxi}], media={mu:.2f} median={med:.2f} moda={mod:.2f} e SSD={SSD:.2f}"
    if verbose: print(stri)

    return n, mu, med, mod, SSD, mini, maxi, stri

n, mu, med, mod, SSD, mini, maxi, stri = mostra_estatistica(nums, verbose=False)
stri

# %% [markdown]
# ### Estatística descritiva

# %% [markdown]
# #### Ordernar os números

# %%
nums.sort()

# %% [markdown]
# #### Valor mínimo

# %%
nums[0]

# %%
int(nums[0])

# %% [markdown]
# #### Valor máximo

# %%
# lembre-se que -1 --> último número da lista
int( nums[-1] )

# %% [markdown]
# #### Quantos elementos?

# %%
len(nums)

# %% [markdown]
# #### Na metadade a mediana !!!

# %%
n2 = int(len(nums)/2)
n2

# %%
int( nums[n2] )

# %% [markdown]
# #### Tudo ok com a mediana?
#
#   - Mediana pode gerar ponto flutuante
#     - 1, 2, 3 --> mediana = 2
#     - 1, 2, 3, 4 --> mediana entre 2 e 3 = 2.5

# %%
np.median(nums)

# %% [markdown]
# #### Boxplot e Quartis
#   - Dividir a série em 4 regiões

# %% [markdown]
# ```
#             |--------------|--------------|
#             |              |              |
# |-----------|              |              |-------------|
#             |              |              |
#             |--------------|--------------|
# mini       1o Q           2o Q           3o Q          maxi
#                          mediana
# ```

# %% [markdown]
# #### Boxplot
#
#    - Dados Uniformemente amostrados: media == mediana  e o gráfico é simétrico

# %%
plt.figure(figsize=(7,3))
sns.set_palette("Blues")
ax = sns.boxplot(x=nums, color='orange')
plt.title("Boxplot da dados uniformemente amostrados");

# %%
### na vertical

# sns.boxplot(data=df, df.altura, orient='vertical', color='orange')

# %%
N

# %%
n4 = int(N/4)

# nums já está ordenado
# (list)  nums.sort()

mini = int( nums[0] )
q1   = int( nums[n4] )
mediana = int( nums[n4*2] )
q3   = int( nums[n4*3] )
maxi = int( nums[-1] )

f"mínimo {mini}, Q1 {q1}, mediana {mediana}, Q3 {q3}, máximo {maxi}"

# %%
mini, q1, mediana, q2, maxi = np.quantile(nums, [0, 0.25, 0.5, 0.75, 1])
f"mínimo {mini}, Q1 {q1}, mediana {mediana}, Q3 {q3}, máximo {maxi}"

# %% [markdown]
# ### Lembra de p-valor - achar valores limites num sequência de valores

# %% [markdown]
# #### Quantos números simulados (random) estão abaixo de 0.025 (2.5%)

# %%
len(nums)

# %%
n25 = int(N*0.025)
n25

# %% [markdown]
# #### valor superior da série 0.025

# %%
nums025 = nums[:n25]
nums025

# %%
### valor sumperior
nums025[-1]

# %% [markdown]
# #### Quantos números simulados (random) estão acima de 0.975 (2.5%)

# %%
# 2.5% últimos
n975 = int(N*0.975)
n975

# %% [markdown]
# #### valor inferior da série 0.975

# %%
nums975 = nums[n975:]
nums975

# %%
# primeiro da série de 2.5% à direita
int(nums975[0])

# %% [markdown]
# ### Quero 2 gráficos com eixo x compartilhado ('alinhados')

# %% [markdown]
# um ao lado do outro
# seria 2 linhas e 1 coluna
#
# plt.subplots(1, 2 ....sharex=True)

# %%
sns.set(style="white", palette="muted", color_codes=True)

# Set up the matplotlib figure
# f, axes = plt.subplots(nrows, ncols ...)
# share - compartilhar - eixo x
f, axes = plt.subplots(2, 1, figsize=(10,6), sharex=True)
sns.despine(left=True)

ax = sns.histplot(nums, bins=divs, color='darkcyan', ax=axes[0])
ax.set_ylabel("Contagem")
ax.set_title("Gráfico de Frequência - dados uniformemente amostrados")

ax = sns.boxplot(x=nums, color='orange', ax=axes[1])
ax.set_title("Boxplot")

# plt.tight_layout()

# %%
# metodo estatístico
def mostra_estatistica(lista: list, verbose:bool=False):

    mini = np.min(lista)
    maxi = np.max(lista)

    mu = np.mean(lista)
    med = np.median(lista)
    moda = mode(lista)

    SSD = np.std(lista)

    N = len(lista)
    n4 = int(N/4)

    lista = list(lista)
    lista.sort()

    mini = int( lista[0] )
    q1   = int( lista[n4] )
    #-- não fiz tratamento correto!
    mediana = int( lista[n4*2] )
    q3   = int( lista[n4*3] )
    maxi = int( lista[-1] )

    s_quantile = f"mínimo {mini}, Q1 {q1}, mediana {mediana}, Q3 {q3}, máximo {maxi}"

    stri = f"N={N} - media={mu:.2f} median={med:.2f} moda={mod:.2f} e SSD={SSD:.2f}"
    if verbose:
      print(stri)
      print(s_quantile)

    return n, mu, q1, med, q2, mod, SSD, mini, maxi, stri, s_quantile

N = 1000
divs = 40

nums = np.random.randint(1, divs+1, N)

n, mu, q1, med, q2, mod, SSD, mini, maxi, stri, s_quantile = mostra_estatistica(nums, verbose=True)

# %% [markdown]
# ### Poderíamos dividir o espaço amostral das seguintes formas:
#
#   - 4 divisões (25% cada) - quartis
#   - 10 divisões (10% cada) - decis
#   - 100 divisões (1% cada) - percentis
#
# Percentis é utilizado em curvas de crescimento

# %% [markdown]
# ### Curva de crescimento em percentis (CDC)

# %% [markdown]
# ![curva de percentil de crescimento](../figure/comprimento_x_idade_peso.gif)
