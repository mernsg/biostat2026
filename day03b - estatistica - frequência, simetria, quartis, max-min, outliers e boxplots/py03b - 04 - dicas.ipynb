# %% [markdown]
# ## Dicas

# %% [markdown]
# ### Duke University - estatística e Python
#
# https://people.duke.edu/~ccc14/sta-663/UsingNumpySolutions.html

# %% [markdown]
# ### OpenStax
#
#   - Clique: Table of Contents
#
# https://openstax.org/details/books/statistics

# %% [markdown]
# ### Estatística e Estudos Clínicos
#
#   - Conceitos de estudos clínicos: básico
#   - Estatística
#
# https://www.scribbr.com/methodology/types-of-variables/

# %% [markdown]
# ### Bookdown - estatística e R
#
#   - Bem completo
#   - Código em R
#
# https://bookdown.org/thomas_pernet/Tuto/random-variables-and-probability-distribution.html
