# %% [markdown]
# ## Formas de armazenamento de dados em memória
#
# ### Tuplas e Sets
#
# #### Reveja lista - escrevo entre colchetes

# %%
# isto é uma lista
mat = [2,3,4,5,6,7]

# %%
mat, len(mat), type(mat)

# %% [markdown]
# ## Tupla - escrevo entre parênteses

# %%
tupla = (2, 3, 5, 8)
tupla, len(tupla), type(tupla)

# %%
# tupla é um bag: uma sacola, mas posso filtrar elementos
tupla[1: 3]

# %% [markdown]
# ### Lista posso organizar; e tupla?

# %%
lista = [3, 8, 2, 9, 11, 4, 7, 15, 17, 0]
lista

# %%
# a função sort já devolve o resultado no seu elemento
# não preciso (devo) fazer: lista = lista.sort()
lista.sort()
lista

# %% [markdown]
# ## Tupla: não posso organizar

# %%
tupla.sort()

# %% [markdown]
# ## Sets: sets são listas sem repetição

# %%
lista = [4, 5, 8, 2, 4, 3, 5, 9, 12]
print(len(lista), type(lista))

# criando s1 com dados da lista
s1 = set( lista )
print(len(s1), type(s1))

# %%
s1, type(s1)

# %% [markdown]
# ## O que mudou?

# %% [markdown]
# ## Set é muito restrito, você não consegue filtrar elementos como em list

# %%
s1[0]

# %%
s1[2:4]

# %% [markdown]
# ## Mas, você consgue iterar

# %%
for elem in s1:
  print(elem)

# %% [markdown]
# ## Você pode forçar um set para ser uma lista, e aí tem todas as funções da lista

# %%
s2 = list(s1)
len(s2), type(s2), s2

# %% [markdown]
# ## Como consigo mitetizar um Set com lista?

# %%
lista = [4, 5, 8, 2, 4, 3, 5, 9, 12]
print(len(lista), type(lista))

# %%
import numpy as np

# %%
lista2 = np.unique(lista)
print(len(lista2), type(lista2))

# %%
lista2

# %%
list(lista2) == list(s2)

# %% [markdown]
# ## O set é uma lista em repetição ordenada
# ### lista.sort() - ordena uma lista
# ### np.unique(lista) - ordena e tira repetidos

# %% [markdown]
# ### Tupla -> Set

# %%
tup = (2, 3, 3, 5, 4, 9)
tup, type(tup)

# %%
set1 = set(tup)
set1, type(set1)
