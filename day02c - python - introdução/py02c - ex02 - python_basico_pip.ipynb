# %% [markdown]
# ## Abrindo bibliotecas

# %%
import os, sys

# %% [markdown]
# ## Abrindo Biopython: algum problema?

# %%
from Bio import SeqIO

# %% [markdown]
# ### Caso a biblioteca não exista, temos que instalá-la
#   - depois de rodar o pip, comente a linha com um #

# %%
# !pip install biopython

# %%
from Bio import SeqIO

# %% [markdown]
# ### Tudo ok, prosseguindo

# %%
from Bio import SeqIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord

import numpy as np

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

# %% [markdown]
# ## Python básico

# %%
a = 1
print(a)

# %%
a = 2
a

# %%
b=3
a+b

# %% [markdown]
# ### Qual o erro?

# %%
a+b+c

# %%
try:
  result = a+b+c
except Exception as e:
  print(e, ' --> a variável c não existe ainda.')

# %%
c = 4

try:
  result = a+b+c
  print(f'Todas variáveis existem: a+b+c = {result}')
except Exception as e:
  print(e, ' --> variável c não existe ainda.')

# %% [markdown]
# ## Listas

# %%
lista = [2, 3, 4, 5]
lista, type(lista)

# %%
lista[0]

# %%
lista[1]

# %% [markdown]
# ## Loop de lista

# %%
for num in lista:
  print(num)

# %% [markdown]
# ### Iterando por posição

# %%
for i in range(len(lista)):
  print(i, lista[i])

# %% [markdown]
# ## Biblioteca numpy (np)
# ### Criando uma lista

# %%
np.arange(5)

# %%
lista = np.arange(5)
lista

# %%
for i in range(len(lista)):
  print(i, lista[i])

# %% [markdown]
# ## Construindo suas próprias funções

# %%
def getDnaNucleotides():
    return ['A','T','G','C']

def getDnaNucleotideString():
    return 'ATGC'

def getRnaNucleotides():
    return ['A','U','G','C']

def getSeqAA():
    return ['A', 'M', 'C', 'F', 'L', 'V', 'I', 'G', 'T', 'S', 'W', 'Y', 'P', 'H', 'N', 'D', 'E', 'Q', 'K', 'R']

def getAaPos(string, aa):
    return string.find(aa)

# %%
getDnaNucleotides()

# %%
lista = getDnaNucleotides()
lista

# %%
# pegar cada nucleotídeo
for nuc in lista:
  print(nuc)
