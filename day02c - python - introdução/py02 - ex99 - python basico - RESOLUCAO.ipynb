# %% [markdown]
# ## Exercício semana 1 - resolvendo

# %% [markdown]
# ## Exemplo 1

# %%
# importando numpy
import numpy as np
# importando o matplotlib
import matplotlib.pyplot as plt

# definindo que a exportação da imagem é no notebook inline
# %matplotlib inline

# %%
# uma lista pode ser criada utilizando-se np.arange()
lista = np.arange(0, 11)
lista

# %%
# repare que esta lista é um np.array
type(lista)

# %%
# pode-se aplicar funções a lista do tipo np.array

lista2 = lista*2
lista2

# %%
# ou elevá-la ao quadradado
lista2 = lista**2
lista2

# %% [markdown]
# ### Vamos criar uma função quadrática, para tanto
#
# 1. criar uma lista_x
# 2. gerar o quadrado da lista_x e por em lista_y
# 3. plotar no matplotlib

# %%
xs = np.arange(0, 100)
# os 10 primeiros elementos
xs[:10]

# %%
# vamos dividir cada elemento pelo valor 5
xs = xs/5
# repare que o 0 é optativo: xs[0:10] == xs[:10]
xs[:10]

# %%
# vamos gerar o valor quadrático
ys = xs * xs
ys[:10]

# %% [markdown]
# ### Plotando com o matplotlib

# %%
fig = plt.figure(figsize = (12,8))

plt.plot(xs, ys, color='green', linewidth=2)
plt.title('função quadrática')
plt.xlabel("seq x")
plt.ylabel("y = x**2");

# %% [markdown]
# ## Primeiro desafio
#   - repita esta função quadrática mas com xs variando de [-5 ... até ... 5]

# %%
xs = np.arange(-5, 6)
xs

# %%
xs = np.arange(-50, +51)
xs

# %% [markdown]
# ## Dado que xs é um numpy array posso dividir 10

# %%
xs = xs / 10
xs

# %% [markdown]
# ### Tem uma outra função no numpy: linspace()

# %%
lista = np.linspace(start=-5, stop=5, num=101)
lista

# %% [markdown]
# ## Agora podemos plotar a função quadrática simetricamente

# %%
ys = xs**2

# %%
fig = plt.figure(figsize = (12,8))

plt.plot(xs, ys, color='green', linewidth=2)
plt.title('função quadrática')
plt.xlabel("seq x")
plt.ylabel("y = x**2");

# %% [markdown]
# ### Posso definir limites para o plot

# %%
fig = plt.figure(figsize = (12,8))

plt.plot(xs, ys, color='green', linewidth=2)
plt.title('função quadrática')
plt.xlabel("seq x")
plt.ylim(0,25)
plt.ylabel("y = x**2");

# %% [markdown]
# ### Posso coloar uma linha vertical em x = 0

# %%
fig = plt.figure(figsize = (12,8))

plt.plot(xs, ys, color='green', linewidth=2)
plt.title('função quadrática')
plt.xlabel("seq x")
plt.ylim(0,25)
plt.axvline(x = 0, color = 'darkred')
plt.ylabel("y = x**2");

# %% [markdown]
# ## Segundo desafio
#   - repita esta função mas na forma cúbica: y = x***3

# %%
ys3 = xs**3

# %%
fig = plt.figure(figsize = (12,8))

plt.plot(xs, ys3, color='green', linewidth=2)
plt.title('função cúbica')
plt.xlabel("seq x")
plt.ylim(0,25) # erro !
plt.axvline(x = 0, color = 'darkred')
plt.ylabel("y = x**3");

# %% [markdown]
# ### ops ... faltou um pedaço do lado negativo ! o que fazer?

# %%
np.min(ys3), np.max(ys3)

# %%
fig = plt.figure(figsize = (12,8))

plt.plot(xs, ys3, color='green', linewidth=2)
plt.title('função cúbica')
plt.xlabel("seq x")
plt.ylim(-125,125)
plt.xlim(-5, 5)
plt.axvline(x = 0, color = 'darkred')
plt.axhline(y = 0, color = 'darkred')
plt.ylabel("y = x**3");

# %% [markdown]
# ## Terceiro desafio
#   - crie e plote a função: y = 2*x + 3

# %%
ys_linear = 2*xs + 3
np.min(ys_linear), np.max(ys_linear)

# %%
fig = plt.figure(figsize = (12,8))

plt.plot(xs, ys_linear, color='green', linewidth=2)
plt.title('função linear')
plt.xlabel("seq x")
plt.ylim(-10,15)
plt.xlim(-5.2, 5.2)
plt.axvline(x = 0, color = 'darkred')
plt.axhline(y = 0, color = 'darkred')
plt.ylabel("y = 2*x + 3");

# %% [markdown]
# ### Colocar texto

# %%
## raiz da função
## 0 = 2*x + 3

x = -3/2

# %%
fig = plt.figure(figsize = (12,8))

plt.plot(xs, ys_linear, color='green', linewidth=2)
plt.title('função linear')
plt.xlabel("seq x")
plt.ylim(-10,15)
plt.xlim(-5.2, 5.2)
plt.axvline(x = 0, color = 'darkred')
plt.axhline(y = 0, color = 'darkred')

# anotação
plt.annotate('coeficiente angular = +3', (0.2,3))
plt.annotate('raiz da função = -1.5', (-1.5,0.2))

plt.arrow(x=-1, y=3, dx=0.6, dy=0, color='black', head_width=.3)
plt.arrow(x=-1.5, y=-1, dx=0, dy=0.6, color='black', head_width=.3)

plt.ylabel("y = 2*x + 3");

# %% [markdown]
# ### Podemos colocar os valores nos eixos ....

# %%
xs_ticks = np.arange(-5,6)
xs_ticks

# %%
ys_ticks = np.arange(-10,16)
ys_ticks

# %%
fig = plt.figure(figsize = (12,8))

plt.plot(xs, ys_linear, color='green', linewidth=2)
plt.title('função linear')
plt.xlabel("seq x")
plt.ylim(-10,15)
plt.xlim(-5.2, 5.2)
plt.axvline(x = 0, color = 'darkred')
plt.axhline(y = 0, color = 'darkred')

# anotação
plt.annotate('coeficiente linear = +3', (0.2,3))
plt.annotate('raiz da função = -1.5', (-1.5,0.2))

plt.xticks(xs_ticks, rotation=90)
plt.yticks(ys_ticks, rotation=0)

plt.arrow(x=-5, y=3, dx=4.6, dy=0, color='black', head_width=.3)
plt.arrow(x=-1.5, y=-10, dx=0, dy=9, color='black', head_width=.3, head_length=1)

plt.ylabel("y = 2*x + 3")
plt.grid()
