# %% [markdown]
# ### Primeiro exemplo
#
# shift + << enter >> = processa a célula e avança
#
# CTRL + << enter >> = processa a célula e NÃO avança

# %%
a = 1
b = 2
c = 3

# %%
a

# %%
a, b, c

# %%
a + b

# %%
b * c

# %%
res = b**c
res

# %% [markdown]
# ### Frase para ser preenchida por valores em memória
#
# f"b elevado res = {b ** c} = num"
#
#   - var - número inteiro
#   - var - float (ponto flutuante)
#   - var - string (caracteres)

# %% [markdown]
# ### Formatdor de string

# %%
b**c

# %%
f"b elevado c = {b**c} = {res}"

# %% [markdown]
# ### Variáveis float (ponto flutuante)

# %%
x = 2.34
y = 2/3

x*y

# %% [markdown]
# ### Carregar o numpy

# %%
import numpy as np

# %%
np.round(x*y, 3)

# %%
f"O resultado da multiplica é {x*y:.3f}"

# %% [markdown]
# ### Variáveis lógicas: boolean

# %%
x, y

# %%
# Lógica = logical = [True, False]
x == y

# %% [markdown]
# ### Ponto flutuante

# %%
x != y

# %%
f"eu sou um float {x*y}"

# %%
# formatação antiga
"eu sou um float %.2f"%(x*y)

# %%
# formatação nova
f"eu sou um float {x*y:.2f}"

# %% [markdown]
# ### Strings
#
#   - Carambolas: o Python soma strings!
#   - Tudo é possível fazer: faça
#   - Sempre faça no processo mais fácil

# %%
str1 = "uma proteína"
str2 = "é composta de aminoácidos"

str1 + ' ' + str2

# %%
"%s + %s"%(str1, str2)

# %%
f"{str1} + {str2}"

# %%
stri = 'LLLCCYW'
stri

# %%
lista_letras = list(stri)
lista_letras

# %%
"minha proteína '%s' tem %d aminoácidos"%(stri,  len(lista_letras) )

# %%
f"minha proteína {stri} tem {len(lista_letras)} aminoácidos"
